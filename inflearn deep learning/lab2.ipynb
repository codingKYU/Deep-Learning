# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.compat.v1.disable_eager_execution()

# %%
x_train = [1,2,3]
y_train = [1,2,3]

# %%
w = tf.Variable(tf.random.normal([1]),name = 'weight')
b = tf.Variable(tf.random.normal([1]),name ='bias')

# %%
hypothesis = x_train * w +b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# %%
sess = tf.compat.v1.Session()
sess.run(tf.initialize_all_variables())
# Out:
# WARNING:tensorflow:From C:\Users\jlee0\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\util\tf_should_use.py:235: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.

# %%
for step in range(2001):
    sess.run(train)
    if step % 20 == 0 :
        print(step, sess.run(cost),sess.run(w),sess.run(b))
# Out:
# 0 0.5345363 [0.36741027] [0.7477276]
# 20 0.10016894 [0.6153839] [0.80859315]
# 40 0.08748164 [0.6542404] [0.779734]
# 60 0.07942057 [0.67246866] [0.74395984]
# 80 0.072130755 [0.6880498] [0.7090794]
# 100 0.065510325 [0.7027282] [0.67576313]
# 120 0.059497487 [0.71670073] [0.6440054]
# 140 0.054036558 [0.73001486] [0.61373955]
# 160 0.0490769 [0.74270314] [0.5848961]
# 180 0.04457241 [0.7547951] [0.5574082]
# 200 0.040481366 [0.7663189] [0.5312121]
# 220 0.03676586 [0.777301] [0.50624704]
# 240 0.0333913 [0.78776705] [0.48245528]
# 260 0.030326536 [0.7977413] [0.45978165]
# 280 0.027543036 [0.8072467] [0.43817365]
# 300 0.02501505 [0.81630534] [0.4175811]
# 320 0.022719057 [0.8249383] [0.39795637]
# 340 0.02063384 [0.8331655] [0.37925392]
# 360 0.018739957 [0.8410061] [0.3614304]
# 380 0.017019931 [0.84847826] [0.34444448]
# 400 0.015457782 [0.8555993] [0.32825682]
# 420 0.014039003 [0.8623856] [0.31283]
# 440 0.012750447 [0.86885285] [0.29812816]
# 460 0.011580166 [0.8750163] [0.28411728]
# 480 0.010517278 [0.88089013] [0.27076474]
# 500 0.00955198 [0.88648784] [0.25803977]
# 520 0.00867525 [0.89182246] [0.2459129]
# 540 0.007879005 [0.8969064] [0.23435596]
# 560 0.0071558505 [0.9017514] [0.22334214]
# 580 0.0064990465 [0.90636873] [0.21284586]
# 600 0.005902535 [0.91076905] [0.20284292]
# 620 0.005360777 [0.9149626] [0.19331002]
# 640 0.0048687574 [0.91895896] [0.1842252]
# 660 0.004421879 [0.9227676] [0.17556731]
# 680 0.0040160227 [0.92639726] [0.16731633]
# 700 0.0036474105 [0.92985636] [0.15945308]
# 720 0.0033126392 [0.9331528] [0.15195939]
# 740 0.0030085964 [0.93629444] [0.14481784]
# 760 0.0027324501 [0.93928826] [0.13801195]
# 780 0.0024816555 [0.94214153] [0.13152589]
# 800 0.0022538786 [0.9448607] [0.12534465]
# 820 0.002047016 [0.947452] [0.11945392]
# 840 0.0018591286 [0.94992155] [0.11384004]
# 860 0.0016884912 [0.95227504] [0.10848999]
# 880 0.0015335133 [0.954518] [0.10339136]
# 900 0.0013927628 [0.95665544] [0.09853236]
# 920 0.001264935 [0.95869243] [0.09390172]
# 940 0.0011488312 [0.96063375] [0.0894887]
